# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/nate/miniforge3/envs/wnv/lib/python3.10/site-packages', '/home/nate/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpewcs0y8i/file/home/nate/analysis/2022-10-10_wnv/workflow/rules/../notebooks', '/home/nate/analysis/2022-10-10_wnv/workflow/rules/../notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95l\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c$data/whole_transmission_lineages.csv\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x15transmission_lineages\x94K\x00N\x86\x94s\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x12\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x18)}\x94\x8c\x05_name\x94h\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bh\x0eh\nub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c5analyses/plots/figureX_transmission-lineage-count.pdf\x94\x8c4analyses/plots/figureX_transmission-lineage-size.pdf\x94\x8c6analyses/plots/figureX_transmission-lineage-length.pdf\x94\x8c>analyses/plots/figureX_transmission-lineage-count-post2002.pdf\x94\x8c=analyses/plots/figureX_transmission-lineage-size-post2002.pdf\x94\x8c?analyses/plots/figureX_transmission-lineage-length-post2002.pdf\x94e}\x94(h\x0c}\x94(\x8c\x0ftl_count_figure\x94K\x00N\x86\x94\x8c\x0etl_size_figure\x94K\x01N\x86\x94\x8c\x10tl_length_figure\x94K\x02N\x86\x94\x8c\x14tl_post_count_figure\x94K\x03N\x86\x94\x8c\x13tl_post_size_figure\x94K\x04N\x86\x94\x8c\x15tl_post_length_figure\x94K\x05N\x86\x94uh\x10]\x94(h\x12h\x13eh\x12h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bh.h&h0h'h2h(h4h)h6h*h8h+ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x10]\x94(h\x12h\x13eh\x12h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x10]\x94(h\x12h\x13eh\x12h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x10]\x94(h\x12h\x13eh\x12h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bhiK\x01hkK\x01hmhfub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c,analyses/figureX_transmission-lineages.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x10]\x94(h\x12h\x13eh\x12h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x12sNt\x94bh\x13h\x16h\x18\x85\x94R\x94(h\x18)}\x94h\x1ch\x13sNt\x94bh\x7fh|ub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x1fplot_transition_lineage_metrics\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c>/home/nate/analysis/2022-10-10_wnv/workflow/rules/../notebooks\x94ub."); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/nate/analysis/2022-10-10_wnv');
######## snakemake preamble end #########

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import plot_horizontal_ballline_plot, setup_plotting_standards

setup_plotting_standards()

cmap = {
    "South" : "#e41a1c",
    "Midwest" : "#377eb8",
    "NorthEast" : "#4daf4a",
    "West" : "#984ea3",
}

# %% [markdown]
# ### Figure X. Transmission lineage characteristics are different in the Eastern and Western US.
# Using the discrete state reconstructions, we determined whether geographic clustering has affected transmission dynamics.

# %% [markdown]
# First we load in the transmission lineages. These were calculated as part rule `beast_analysis.identify_transmission_lineages`. Briefly, we follow Du Plessis et al. 2020 in defining transmission lineages as two or more taxa belonging to the same state descend from a shared, single importation of the virus into the state from any other state.

# %%
tl = pd.read_csv( snakemake.input.transmission_lineages )

print( f"{tl.shape[0]} lineages found." )
print( f"{tl.loc[tl['children']>1].shape[0]} non-singleton lineages found.")
print()

tlong = tl.loc[tl['children']>1].copy()
tlong["length"] = tlong["latest_date"] - tlong["height"]

tlong.head()
# Out:
# 686213 lineages found.
# 180731 non-singleton lineages found.
#    Location  Location.rate par.Location  children  \
# 0   Arizona       0.043634   California         2
# 8   Arizona       0.043634   California         2
# 10  Arizona       0.043634        Texas         2
# 12  Arizona       0.043634    Minnesota         4
# 14  Arizona       0.043634        Texas         8
#
#                                        children.names  earliest_date  \
# 0   ['DQ666451|USA|nan|2005-06-01|nan|nan', 'KJ501...    2005.413584
# 8   ['DQ080053|USA|Arizona-Apache|2003-06-01|nan|n...    2003.413584
# 10  ['MG004533|USA|Arizona-Maricopa|2014-06-03|nan...    2014.419064
# 12  ['KJ501442|USA|Arizona|2010-05-19|nan|nan', 'K...    2010.377968
# 14  ['MG004535|USA|Arizona-Maricopa|2014-07-22|nan...    2014.553311
#
#     latest_date                                     children.dates  \
# 0   2005.610845           [2005.4135844748857, 2005.6108447488584]
# 8   2003.413584           [2003.4135844748857, 2003.4135844748857]
# 10  2015.358790            [2014.4190639269407, 2015.358789954338]
# 12  2014.482078  [2010.3779680365296, 2010.6026255707764, 2014....
# 14  2017.314954  [2014.553310502283, 2017.3149543378995, 2015.7...
#
#          height  tree    length
# 0   2004.279094   110  1.331751
# 8   2001.935857   110  1.477727
# 10  2014.283436   110  1.075354
# 12  2007.775556   110  6.706522
# 14  2013.191569   110  4.123385

# %% [markdown]
# Here we plot the median number of transmission lineages for each state. This generates figure X.

# %%
plot_df = tlong.pivot_table( index="tree", columns="Location", values="par.Location", aggfunc="count" ).describe(percentiles=[0.025, 0.5, 0.975]).T
fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(0,25), xlabel="Transmission lineages", sortby=["50%", "97.5%"] )
plt.tight_layout()
fig.savefig( snakemake.output.tl_count_figure )
plt.show()

# %% [markdown]
# Here, we plot the median number of descendents for each states' transmission lineages. This generates figure X.

# %%
plot_df = tlong.groupby( "Location" )["children"].describe( percentiles=[0.025, 0.5, 0.975])

fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(1,1000), xlabel="Descendents", sortby=["50%", "97.5%"] )
ax.set_xscale( "log" )
ax.tick_params( axis="x", direction="in", which="both", labelbottom=True, pad=3 )
plt.tight_layout()
fig.savefig( snakemake.output.tl_size_figure )
plt.show()

# %% [markdown]
# Here we plot the median length of transmission lineages from each state. This generates figure X.

# %%
plot_df = tlong.groupby( "Location" )["length"].describe( percentiles=[0.025, 0.5, 0.975])

fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(0,17), xlabel="Length (years)", sortby=["50%"] )
plt.tight_layout()
fig.savefig( snakemake.output.tl_length_figure )
plt.show()

# %% [markdown]
# #### Post-2002
# Dellicour et al. 2020 found that the dispersal of West Nile virus changed after it rapid expansion following its introduction in ~1999. Specifically, they found that the dispersal speed dropped after 2002 indicating the begining of geographic clustering. Consequently, the massive polytomy resulting from its early spread and its consistent assignment to New York and Connecticut, might be influencing our results. Thus, we compute the exact same graphs as above but only considering transmission lineages occuring after 2002.

# %%
tlong = tlong.loc[tlong["height"]>2002]
plot_df = tlong.pivot_table( index="tree", columns="Location", values="par.Location", aggfunc="count" ).describe(percentiles=[0.025, 0.5, 0.975]).T
fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(0,20), xlabel="Transmission lineages", sortby=["50%", "97.5%"] )
plt.tight_layout()
fig.savefig( snakemake.output.tl_post_count_figure )
plt.show()

# %%
plot_df = tlong.groupby( "Location" )["children"].describe( percentiles=[0.025, 0.5, 0.975])

fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(1,1000), xlabel="Descendents", sortby=["50%", "97.5%"] )
ax.set_xscale( "log" )
ax.tick_params( axis="x", direction="in", which="both", labelbottom=True, pad=3 )
plt.tight_layout()
fig.savefig( snakemake.output.tl_post_size_figure )
plt.show()

# %%
plot_df = tlong.groupby( "Location" )["length"].describe( percentiles=[0.025, 0.5, 0.975])

fig, ax = plt.subplots( dpi=200, figsize=(4,6) )
plot_horizontal_ballline_plot( ax, plot_df, cmap, xlims=(0,15), xlabel="Length (years)", sortby=["50%"] )
plt.tight_layout()
fig.savefig( snakemake.output.tl_post_length_figure )
plt.show()
